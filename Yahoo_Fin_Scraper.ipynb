# %%
import yahoo_fin.stock_info as si

# %%
si.get_financials('gm')
# Out:
# {'yearly_income_statement': endDate                              2021-12-31    2020-12-31    2019-12-31  \
#  Breakdown
#  researchDevelopment                        None          None          None
#  effectOfAccountingCharges                  None          None          None
#  incomeBeforeTax                     12716000000    8095000000    7436000000
#  minorityInterest                     6071000000    4647000000    4165000000
#  netIncome                           10019000000    6427000000    6732000000
#  sellingGeneralAdministrative         6645000000    5943000000    7694000000
#  grossProfit                         18079000000   14502000000   14138000000
#  ebit                                11434000000    8559000000    6444000000
#  operatingIncome                     11434000000    8559000000    6444000000
#  otherOperatingExpenses                     None          None          None
#  interestExpense                      -950000000   -1098000000    -782000000
# ...

# %%
si.get_earnings_history('gm')
# Out:
# [{'ticker': 'GM',
#   'companyshortname': 'General Motors Co',
#   'startdatetime': '2023-04-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'GM',
#   'companyshortname': 'General Motors Co',
#   'startdatetime': '2023-01-30T21:00:00.000Z',
#   'startdatetimetype': 'AMC',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'GM',
#   'companyshortname': 'General Motors Co',
#   'startdatetime': '2022-10-25T12:30:00.000Z',
#   'startdatetimetype': 'BMO',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'GM',
# ...

# %%
si.get_balance_sheet('gm')
# Out:
# endDate                         2021-12-31    2020-12-31    2019-12-31  \
# Breakdown
# intangibleAssets                3748000000    3887000000    3982000000
# capitalSurplus                 27061000000   26542000000   26074000000
# totalLiab                     178903000000  185517000000  182080000000
# totalStockholderEquity         59744000000   45030000000   41792000000
# minorityInterest                6071000000    4647000000    4165000000
# otherCurrentLiab                6230000000    6180000000    6221000000
# totalAssets                   244718000000  235194000000  228037000000
# commonStock                       15000000      14000000      14000000
# otherCurrentAssets              4105000000    5217000000    5751000000
# retainedEarnings               41937000000   31962000000   26860000000
# otherLiab                      27824000000   31657000000   30241000000
# treasuryStock                  -9269000000  -13488000000  -11156000000
# ...

# %%
si.get_income_statement('gm')
# Out:
# endDate                              2021-12-31    2020-12-31    2019-12-31  \
# Breakdown
# researchDevelopment                        None          None          None
# effectOfAccountingCharges                  None          None          None
# incomeBeforeTax                     12716000000    8095000000    7436000000
# minorityInterest                     6071000000    4647000000    4165000000
# netIncome                           10019000000    6427000000    6732000000
# sellingGeneralAdministrative         6645000000    5943000000    7694000000
# grossProfit                         18079000000   14502000000   14138000000
# ebit                                11434000000    8559000000    6444000000
# operatingIncome                     11434000000    8559000000    6444000000
# otherOperatingExpenses                     None          None          None
# interestExpense                      -950000000   -1098000000    -782000000
# ...

# %%
import datetime as dt
start_date = dt.datetime.strptime('01/01/2018', "%m/%d/%Y")
end_date = start_date + dt.timedelta(days=50)
data = si.get_data('msft' , start_date = start_date.strftime("%m/%d/%Y") , end_date = end_date.strftime("%m/%d/%Y"))
data2 = si.get_data('amzn' , start_date = start_date.strftime("%m/%d/%Y") , end_date = end_date.strftime("%m/%d/%Y"))
# print(start_date)
# print(end_date)
# start_date.strftime("%m/%d/%Y")

# %%
import pandas as pd

pd.concat([data,data2])
# Out:
#                    open         high          low        close     adjclose  \
# 2018-01-02    86.129997    86.309998    85.500000    85.949997    81.340797
# 2018-01-03    86.059998    86.510002    85.970001    86.349998    81.719330
# 2018-01-04    86.589996    87.660004    86.570000    87.110001    82.438576
# 2018-01-05    87.660004    88.410004    87.430000    88.190002    83.460648
# 2018-01-08    88.199997    88.580002    87.599998    88.279999    83.545845
# ...                 ...          ...          ...          ...          ...
# 2018-02-12  1364.670044  1393.810059  1344.010010  1386.229980  1386.229980
# 2018-02-13  1385.930054  1419.719971  1383.530029  1414.510010  1414.510010
# 2018-02-14  1406.250000  1452.060059  1403.359985  1451.050049  1451.050049
# 2018-02-15  1466.890015  1468.939941  1436.839966  1461.760010  1461.760010
# 2018-02-16  1457.369995  1465.800049  1446.560059  1448.689941  1448.689941
#
#               volume ticker
# ...
