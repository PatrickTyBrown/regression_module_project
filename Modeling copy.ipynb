# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Data/data_ready.csv')
df['const'] = 1
df.head()
# Out:
#    Unnamed: 0        date    open    high     low   close     volume ticker  \
# 0           0  2022-06-03   3.500   3.500   2.220   2.560  1629900.0   SVRE
# 1           1  1997-01-31  12.250  12.375  12.000  12.125  1241000.0   CERS
# 2           2  1997-02-03  12.375  12.375  12.125  12.250   179700.0   CERS
# 3           3  1997-02-04  12.250  12.375  12.000  12.000   113200.0   CERS
# 4           4  1997-02-05  12.000  12.375  12.000  12.000   236100.0   CERS
#
#    days_post_ipo  first_day_open  ...     ^IXIC_low   ^IXIC_close  \
# 0              0            3.50  ...  11966.620117  12012.730469
# 1              0           12.25  ...   1374.979980   1379.849976
# 2              3           12.25  ...   1374.569946   1376.050049
# 3              4           12.25  ...   1362.810059   1373.750000
# 4              5           12.25  ...   1339.640015   1348.439941
#
#    ^IXIC_adjclose  ^IXIC_volume     ^NYA_open     ^NYA_high      ^NYA_low  \
# 0    12012.730469    4117290000  15960.530273  15960.530273  15764.839844
# 1     1379.849976     679190000   4356.169922   4356.169922   4356.169922
# 2     1376.050049     537540000   4361.450195   4361.450195   4361.450195
# 3     1373.750000     606160000   4370.549805   4370.549805   4370.549805
# 4     1348.439941     680460000   4321.910156   4321.910156   4321.910156
#
#      ^NYA_close  ^NYA_adjclose  ^NYA_volume
# 0  15797.169922   15797.169922   3107080000
# 1   4356.169922    4356.169922            0
# 2   4361.450195    4361.450195            0
# 3   4370.549805    4370.549805            0
# 4   4321.910156    4321.910156            0
#
# [5 rows x 100 columns]

# %%
df[mask][['close','first_day_open', 'first_day_high',
       'first_day_low', 'first_day_close', 'first_day_volume']]
# Out:
#         close  first_day_open  first_day_high  first_day_low  first_day_close  \
# 4       12.00           12.25       12.375000        12.0000          12.1250
# 5       12.00           12.25       12.375000        12.0000          12.1250
# 6       11.75           12.25       12.375000        12.0000          12.1250
# 95      10.50           11.00       11.000000        10.3125          10.5625
# 96      10.50           11.00       11.000000        10.3125          10.5625
# ...       ...             ...             ...            ...              ...
# 534416  17.76           18.76       20.565001        17.0000          19.0900
# 534417  15.47           18.76       20.565001        17.0000          19.0900
# 534440  13.19           12.50       17.500000         9.6400          10.5900
# 534441  15.19           12.50       17.500000         9.6400          10.5900
# 534442  16.17           12.50       17.500000         9.6400          10.5900
#
#         first_day_volume
# 4              1241000.0
# 5              1241000.0
# 6              1241000.0
# 95            26677600.0
# 96            26677600.0
# ...                  ...
# 534416         2337300.0
# 534417         2337300.0
# 534440         3426600.0
# 534441         3426600.0
# 534442         3426600.0
#
# [10744 rows x 6 columns]

# %% [markdown]
# ## Naive Model

# %%
x_cols = ['const', 'days_post_ipo', 'first_day_open', 'first_day_high',
       'first_day_low', 'first_day_close', 'first_day_volume', 'Employees',
       'Offer amount', 'Shares Over Alloted', 'Total Offering Expense',
       'Shareholder Shares Offered', 'Shares Outstanding', 'Revenue', 'Net Income', 'Total Assets',
       'Total Liabilities', "Stockholders' Equity", 'proposedSharePrice',
       'sharesOffered', 'dollarValueOfSharesOffered', 'Utilities',
       'Technology', 'Services', 'Real Estate', 'Industrials', 'Healthcare',
       'Financial Services', 'Energy', 'Consumer Defensive',
       'Consumer Cyclical', 'Communication Services', 'Basic Materials',
       'Shell Companies', 'Biotechnology', 'Software—Application',
       'Banks—Regional', 'Software—Infrastructure', 'Medical Devices',
       'Drug Manufacturers—Specialty & Generic',
       'Internet Content & Information', 'Internet Retail',
       'Health Information Services', 'Diagnostics & Research',
       'Semiconductors', 'Education & Training Services', 'Asset Management',
       'Oil & Gas Midstream', 'Credit Services',
       'Medical Instruments & Supplies', 'Oil & Gas E&P',
       'Information Technology Services', 'Communication Equipment', 'Asia', 'North America', 'Europe', 'Africa',
       'South America', 'Oceania', '^DJI_open', '^DJI_high', '^DJI_low',
       '^DJI_close', '^DJI_adjclose', '^DJI_volume', '^GSPC_open',
       '^GSPC_high', '^GSPC_low', '^GSPC_close', '^GSPC_adjclose',
       '^GSPC_volume', '^RUT_open', '^RUT_high', '^RUT_low', '^RUT_close',
       '^RUT_adjclose', '^RUT_volume', '^IXIC_open', '^IXIC_high', '^IXIC_low',
       '^IXIC_close', '^IXIC_adjclose', '^IXIC_volume', '^NYA_open',
       '^NYA_high', '^NYA_low', '^NYA_close', '^NYA_adjclose', '^NYA_volume']

y_col = ['close']

# %%
mask = (df.days_post_ipo >= 40) & (df.days_post_ipo < 45)
x = df[mask][x_cols]
y = df[mask]['close'] / df[mask]['first_day_close']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.20, random_state=42)

model = sm.OLS(y_train, X_train)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     5.905
# Date:                Thu, 09 Jun 2022   Prob (F-statistic):           2.70e-40
# Time:                        18:39:21   Log-Likelihood:                -15371.
# No. Observations:                8571   AIC:                         3.086e+04
# Df Residuals:                    8513   BIC:                         3.127e+04
# Df Model:                          57
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                      0.9343      0.531      1.760      0.078      -0.106       1.975
# days_post_ipo                              0.0011      0.013      0.086      0.932      -0.024       0.026
# first_day_open                          7.321e-06   8.36e-05      0.088      0.930      -0.000       0.000
# first_day_high                          1.345e-05   9.58e-05      0.140      0.888      -0.000       0.000
# first_day_low                          -1.368e-05   5.05e-05     -0.271      0.786      -0.000    8.53e-05
# first_day_close                        -8.926e-06      0.000     -0.089      0.929      -0.000       0.000
# first_day_volume                        -2.66e-11   8.19e-10     -0.032      0.974   -1.63e-09    1.58e-09
# Employees                                2.27e-07   1.72e-06      0.132      0.895   -3.14e-06    3.59e-06
# Offer amount                             1.97e-08   1.73e-07      0.114      0.909   -3.19e-07    3.58e-07
# Shares Over Alloted                       -0.2133      0.165     -1.290      0.197      -0.538       0.111
# Total Offering Expense                  3.536e-10   5.03e-09      0.070      0.944   -9.51e-09    1.02e-08
# Shareholder Shares Offered                 0.0658      0.044      1.492      0.136      -0.021       0.152
# Shares Outstanding                      9.787e-13   4.29e-12      0.228      0.820   -7.44e-12    9.39e-12
# Oil & Gas E&P                             -0.0830      0.235     -0.354      0.724      -0.543       0.377
# Information Technology Services           -0.0449      0.203     -0.221      0.825      -0.443       0.354
# Communication Equipment                   -0.0105      0.217     -0.049      0.961      -0.435       0.414
# Asia                                       0.0963      0.105      0.913      0.361      -0.110       0.303
# North America                              0.0891      0.060      1.479      0.139      -0.029       0.207
# Europe                                     0.0399      0.099      0.403      0.687      -0.154       0.234
# Africa                                    -0.1700      1.041     -0.163      0.870      -2.211       1.871
# South America                              0.1071      0.182      0.587      0.557      -0.250       0.464
# Oceania                                   -0.1229      0.332     -0.370      0.712      -0.774       0.529
# ==============================================================================
# Omnibus:                    24678.215   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1040325040.220
# Skew:                          39.229   Prob(JB):                         0.00
# Kurtosis:                    1707.963   Cond. No.                     4.06e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.74e-11. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
model = LinearRegression()
model.fit(X_train, y_train)
r_squared_train = model.score(X_train, y_train)
r_squared_test = model.score(X_test, y_test)

print(f'Train R^2: {r_squared_train}\n Test R^2: {r_squared_test}')
# Out:
# Train R^2: 0.03803367254441559
#  Test R^2: 0.02570401600755512

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'ticker', 'days_post_ipo', 'first_day_open', 'first_day_high',
#        'first_day_low', 'first_day_close', 'first_day_volume', 'Employees',
#        'Offer amount', 'Shares Over Alloted', 'Total Offering Expense',
#        'Shareholder Shares Offered', 'Shares Outstanding', 'Revenue',
#        'first_filing_type', 'first_filing_date', 'Net Income', 'Total Assets',
#        'Total Liabilities', 'Stockholders' Equity', 'proposedSharePrice',
#        'sharesOffered', 'dollarValueOfSharesOffered', 'Utilities',
#        'Technology', 'Services', 'Real Estate', 'Industrials', 'Healthcare',
#        'Financial Services', 'Energy', 'Consumer Defensive',
#        'Consumer Cyclical', 'Communication Services', 'Basic Materials',
#        'Shell Companies', 'Biotechnology', 'Software—Application',
#        'Banks—Regional', 'Software—Infrastructure', 'Medical Devices',
#        'Drug Manufacturers—Specialty & Generic',
#        'Internet Content & Information', 'Internet Retail',
#        'Health Information Services', 'Diagnostics & Research',
#        'Semiconductors', 'Education & Training Services', 'Asset Management',
#        'Oil & Gas Midstream', 'Credit Services',
#        'Medical Instruments & Supplies', 'Oil & Gas E&P',
#        'Information Technology Services', 'Communication Equipment', 'country',
#        'continent', 'Asia', 'North America', 'Europe', 'Africa',
#        'South America', 'Oceania', '^DJI_open', '^DJI_high', '^DJI_low',
#        '^DJI_close', '^DJI_adjclose', '^DJI_volume', '^GSPC_open',
#        '^GSPC_high', '^GSPC_low', '^GSPC_close', '^GSPC_adjclose',
#        '^GSPC_volume', '^RUT_open', '^RUT_high', '^RUT_low', '^RUT_close',
#        '^RUT_adjclose', '^RUT_volume', '^IXIC_open', '^IXIC_high', '^IXIC_low',
#        '^IXIC_close', '^IXIC_adjclose', '^IXIC_volume', '^NYA_open',
#        '^NYA_high', '^NYA_low', '^NYA_close', '^NYA_adjclose', '^NYA_volume'],
#       dtype='object')
